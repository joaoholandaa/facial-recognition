# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import files
imported = files.upload()
print("Imported files:")
print(*imported, sep = "/n")
# Out:
#      <input type="file" id="files-680abaf9-c014-4b1f-88bc-0f27a4d68c3a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-680abaf9-c014-4b1f-88bc-0f27a4d68c3a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving got.jpg to got.jpg
# Imported files:
# got.jpg

# %%
image = cv.imread("got.jpg")

# %%
type(image)
# Out:
# numpy.ndarray

# %%
def show_image(image):
  image_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  plt.imshow(image_rgb)
show_image(image)

# %%
image_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
show_image(image_gray)

# %%
faceCascade = cv.CascadeClassifier(cv.data.haarcascades +
                                   "haarcascade_frontalface_default.xml")

# %%
faces = faceCascade.detectMultiScale(image_gray)

# %%
image_copy = np.array(image)

# %%
for x, y, w, h in faces:
  cv.rectangle(image_copy, (x,y), (x+w, y+h), (0,255,0), 2)
show_image(image_copy)

# %%
images_cropped = list()

# %%
for x, y, w, h in faces:
  face = image[y:y+h, x:x+w]
  face = cv.resize(face, (160,160))
  images_cropped.append(face)

# %%
len(images_cropped)
# Out:
# 4

# %%
for img in images_cropped:
  print(img.shape)
# Out:
# (160, 160, 3)
# (160, 160, 3)
# (160, 160, 3)
# (160, 160, 3)

# %%
show_image(images_cropped[0])

# %%
show_image(images_cropped[1])

# %%
show_image(images_cropped[2])

# %%
show_image(images_cropped[3])
